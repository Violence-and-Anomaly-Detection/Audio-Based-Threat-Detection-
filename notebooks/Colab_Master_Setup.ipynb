# %% [markdown]
# # Multi-Modal Violence Detection - Audio Module Setup
# This notebook handles the environment setup, GitHub sync, and Google Drive mounting for the project.
#
# ### 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2. Clone the Repository
# Replace `[YOUR_GITHUB_REPO_LINK]` with your actual repository link.

# %%
# !git clone [YOUR_GITHUB_REPO_LINK]
# %cd Audio-Based-Threat-Detection

# %% [markdown]
# ### 3. Install Requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 4. Verify GPU Access

# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
  print(f"Device: {torch.cuda.get_device_name(0)}")
